# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

# %%
# Create an empty list to hold the weather data. 
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval        ")
print("--------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_cd = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_cd})

# If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        continue

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 4 of Set 1 | makat
# Processing Record 5 of Set 1 | arraial do cabo
# Processing Record 6 of Set 1 | birin
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | talnakh
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | kulhudhuffushi
# Processing Record 16 of Set 1 | thompson
# Processing Record 17 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | santa marta
# Processing Record 20 of Set 1 | upernavik
# Processing Record 21 of Set 1 | beringovskiy
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | nola
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | madang
# Processing Record 26 of Set 1 | kaitangata
# Processing Record 27 of Set 1 | upata
# Processing Record 28 of Set 1 | mahebourg
# Processing Record 29 of Set 1 | college
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | urdzhar
# City not found. Skipping...
# Processing Record 33 of Set 1 | temozon
# Processing Record 34 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 1 | leningradskiy
# Processing Record 36 of Set 1 | najran
# Processing Record 37 of Set 1 | flinders
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | mingguang
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | cubara
# Processing Record 43 of Set 1 | te anau
# Processing Record 44 of Set 1 | sembe
# Processing Record 45 of Set 1 | saskylakh
# Processing Record 46 of Set 1 | maraa
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | mokhsogollokh
# Processing Record 1 of Set 2 | aksarka
# Processing Record 2 of Set 2 | sao gabriel da cachoeira
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | forest grove
# Processing Record 5 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 2 | puerto escondido
# Processing Record 7 of Set 2 | port blair
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | mujiayingzi
# Processing Record 10 of Set 2 | ilulissat
# Processing Record 11 of Set 2 | san pedro
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | kizukuri
# Processing Record 14 of Set 2 | sabang
# Processing Record 15 of Set 2 | namibe
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | pestyaki
# Processing Record 18 of Set 2 | ugoofaaru
# Processing Record 19 of Set 2 | vila velha
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | mataura
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | iranshahr
# Processing Record 24 of Set 2 | olafsvik
# Processing Record 25 of Set 2 | druzhba
# Processing Record 26 of Set 2 | albany
# Processing Record 27 of Set 2 | camacha
# Processing Record 28 of Set 2 | haines junction
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | nueve de julio
# Processing Record 31 of Set 2 | meshchovsk
# Processing Record 32 of Set 2 | lambarene
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | severnyy
# Processing Record 35 of Set 2 | wahran
# City not found. Skipping...
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | hervey bay
# Processing Record 38 of Set 2 | victoria
# Processing Record 39 of Set 2 | tautira
# Processing Record 40 of Set 2 | airai
# Processing Record 41 of Set 2 | barcelos
# Processing Record 42 of Set 2 | sokoni
# Processing Record 43 of Set 2 | juegang
# Processing Record 44 of Set 2 | takoradi
# Processing Record 45 of Set 2 | chuy
# Processing Record 46 of Set 2 | puerto madryn
# Processing Record 47 of Set 2 | cururupu
# Processing Record 48 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 2 | krasnogorskoye
# Processing Record 50 of Set 2 | doha
# Processing Record 1 of Set 3 | harper
# Processing Record 2 of Set 3 | puerto ayora
# Processing Record 3 of Set 3 | nizhniy odes
# Processing Record 4 of Set 3 | georgetown
# Processing Record 5 of Set 3 | faanui
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 3 | cherskiy
# Processing Record 10 of Set 3 | ponta do sol
# Processing Record 11 of Set 3 | meiktila
# Processing Record 12 of Set 3 | san patricio
# Processing Record 13 of Set 3 | hasaki
# Processing Record 14 of Set 3 | muros
# Processing Record 15 of Set 3 | torbay
# Processing Record 16 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 3 | luan
# Processing Record 18 of Set 3 | eureka
# Processing Record 19 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 3 | rio linda
# Processing Record 21 of Set 3 | nelson bay
# Processing Record 22 of Set 3 | yima
# Processing Record 23 of Set 3 | kodiak
# Processing Record 24 of Set 3 | norman wells
# Processing Record 25 of Set 3 | hofn
# Processing Record 26 of Set 3 | barrow
# Processing Record 27 of Set 3 | anqing
# Processing Record 28 of Set 3 | butaritari
# Processing Record 29 of Set 3 | madingou
# Processing Record 30 of Set 3 | korcula
# Processing Record 31 of Set 3 | bambous virieux
# Processing Record 32 of Set 3 | vyatskiye polyany
# Processing Record 33 of Set 3 | kruisfontein
# Processing Record 34 of Set 3 | sabha
# Processing Record 35 of Set 3 | champerico
# Processing Record 36 of Set 3 | lorengau
# Processing Record 37 of Set 3 | mount isa
# Processing Record 38 of Set 3 | kavaratti
# Processing Record 39 of Set 3 | merauke
# Processing Record 40 of Set 3 | viana
# Processing Record 41 of Set 3 | beruwala
# Processing Record 42 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 3 | litein
# Processing Record 44 of Set 3 | necochea
# Processing Record 45 of Set 3 | kargapolye
# City not found. Skipping...
# Processing Record 46 of Set 3 | gat
# Processing Record 47 of Set 3 | krasnoselkup
# Processing Record 48 of Set 3 | itarema
# Processing Record 49 of Set 3 | nanortalik
# Processing Record 50 of Set 3 | bousso
# Processing Record 1 of Set 4 | hithadhoo
# Processing Record 2 of Set 4 | tunxi
# City not found. Skipping...
# Processing Record 3 of Set 4 | tuatapere
# Processing Record 4 of Set 4 | bethel
# Processing Record 5 of Set 4 | chokurdakh
# Processing Record 6 of Set 4 | say
# Processing Record 7 of Set 4 | puntarenas
# Processing Record 8 of Set 4 | high level
# Processing Record 9 of Set 4 | panguna
# Processing Record 10 of Set 4 | monrovia
# Processing Record 11 of Set 4 | vostok
# Processing Record 12 of Set 4 | tomatlan
# Processing Record 13 of Set 4 | severo-kurilsk
# Processing Record 14 of Set 4 | luvianos
# Processing Record 15 of Set 4 | mahibadhoo
# Processing Record 16 of Set 4 | manokwari
# Processing Record 17 of Set 4 | lavrentiya
# Processing Record 18 of Set 4 | watertown
# Processing Record 19 of Set 4 | ostrovnoy
# Processing Record 20 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 4 | hermanus
# Processing Record 22 of Set 4 | alim
# Processing Record 23 of Set 4 | mandalgovi
# Processing Record 24 of Set 4 | dharchula
# Processing Record 25 of Set 4 | olinda
# Processing Record 26 of Set 4 | berlevag
# Processing Record 27 of Set 4 | kimbe
# Processing Record 28 of Set 4 | diamantino
# Processing Record 29 of Set 4 | ahipara
# Processing Record 30 of Set 4 | faya
# Processing Record 31 of Set 4 | souillac
# Processing Record 32 of Set 4 | juybar
# Processing Record 33 of Set 4 | conde
# Processing Record 34 of Set 4 | juneau
# Processing Record 35 of Set 4 | hambantota
# Processing Record 36 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 4 | sao felix do xingu
# Processing Record 38 of Set 4 | jining
# Processing Record 39 of Set 4 | caravelas
# Processing Record 40 of Set 4 | san andres
# Processing Record 41 of Set 4 | sanming
# Processing Record 42 of Set 4 | xai-xai
# Processing Record 43 of Set 4 | ikom
# Processing Record 44 of Set 4 | cidreira
# Processing Record 45 of Set 4 | teknaf
# Processing Record 46 of Set 4 | linhares
# Processing Record 47 of Set 4 | sokolo
# Processing Record 48 of Set 4 | asau
# Processing Record 49 of Set 4 | pevek
# Processing Record 50 of Set 4 | dingle
# Processing Record 1 of Set 5 | valley
# Processing Record 2 of Set 5 | salalah
# Processing Record 3 of Set 5 | santa cruz
# Processing Record 4 of Set 5 | strunino
# Processing Record 5 of Set 5 | tiksi
# Processing Record 6 of Set 5 | gamba
# Processing Record 7 of Set 5 | coihaique
# Processing Record 8 of Set 5 | mayumba
# Processing Record 9 of Set 5 | hella
# Processing Record 10 of Set 5 | bundaberg
# Processing Record 11 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 12 of Set 5 | mandeville
# Processing Record 13 of Set 5 | santa vitoria do palmar
# Processing Record 14 of Set 5 | west odessa
# Processing Record 15 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 5 | musafirkhana
# Processing Record 17 of Set 5 | bom jesus
# Processing Record 18 of Set 5 | venado tuerto
# Processing Record 19 of Set 5 | cortez
# Processing Record 20 of Set 5 | bayir
# Processing Record 21 of Set 5 | ancud
# Processing Record 22 of Set 5 | lokosovo
# Processing Record 23 of Set 5 | kahului
# Processing Record 24 of Set 5 | pancevo
# Processing Record 25 of Set 5 | urukh
# Processing Record 26 of Set 5 | narsaq
# Processing Record 27 of Set 5 | sao filipe
# Processing Record 28 of Set 5 | walvis bay
# Processing Record 29 of Set 5 | fortuna
# Processing Record 30 of Set 5 | nouakchott
# Processing Record 31 of Set 5 | lompoc
# Processing Record 32 of Set 5 | lincoln
# Processing Record 33 of Set 5 | codrington
# Processing Record 34 of Set 5 | sladkovo
# Processing Record 35 of Set 5 | phonhong
# Processing Record 36 of Set 5 | dera bugti
# Processing Record 37 of Set 5 | hamilton
# Processing Record 38 of Set 5 | magadi
# Processing Record 39 of Set 5 | katsuura
# Processing Record 40 of Set 5 | arrifes
# Processing Record 41 of Set 5 | koson
# Processing Record 42 of Set 5 | alindao
# Processing Record 43 of Set 5 | salinopolis
# Processing Record 44 of Set 5 | saint-pierre
# Processing Record 45 of Set 5 | birao
# Processing Record 46 of Set 5 | clyde river
# Processing Record 47 of Set 5 | pareora
# Processing Record 48 of Set 5 | bani walid
# Processing Record 49 of Set 5 | kawalu
# Processing Record 50 of Set 5 | oriximina
# Processing Record 1 of Set 6 | iqaluit
# Processing Record 2 of Set 6 | vao
# Processing Record 3 of Set 6 | yerkoy
# Processing Record 4 of Set 6 | bukene
# Processing Record 5 of Set 6 | lagunas
# Processing Record 6 of Set 6 | otjiwarongo
# Processing Record 7 of Set 6 | owensboro
# Processing Record 8 of Set 6 | mengcheng
# Processing Record 9 of Set 6 | kaabong
# Processing Record 10 of Set 6 | kudahuvadhoo
# Processing Record 11 of Set 6 | ola
# Processing Record 12 of Set 6 | santa cruz de la palma
# Processing Record 13 of Set 6 | uruzgan
# Processing Record 14 of Set 6 | kushmurun
# Processing Record 15 of Set 6 | bilma
# Processing Record 16 of Set 6 | mackay
# Processing Record 17 of Set 6 | lulea
# Processing Record 18 of Set 6 | ginda
# Processing Record 19 of Set 6 | along
# Processing Record 20 of Set 6 | mehamn
# Processing Record 21 of Set 6 | dikson
# Processing Record 22 of Set 6 | saint-francois
# Processing Record 23 of Set 6 | dakar
# Processing Record 24 of Set 6 | sechura
# Processing Record 25 of Set 6 | nouadhibou
# Processing Record 26 of Set 6 | sambava
# Processing Record 27 of Set 6 | mangochi
# Processing Record 28 of Set 6 | hammerfest
# Processing Record 29 of Set 6 | padang
# Processing Record 30 of Set 6 | paamiut
# Processing Record 31 of Set 6 | fairbanks
# Processing Record 32 of Set 6 | longyearbyen
# Processing Record 33 of Set 6 | anaconda
# Processing Record 34 of Set 6 | maridi
# Processing Record 35 of Set 6 | mattawa
# Processing Record 36 of Set 6 | jiayuguan
# Processing Record 37 of Set 6 | wichita falls
# Processing Record 38 of Set 6 | yantal
# Processing Record 39 of Set 6 | arman
# Processing Record 40 of Set 6 | liepaja
# Processing Record 41 of Set 6 | tatawin
# Processing Record 42 of Set 6 | verkhoyansk
# Processing Record 43 of Set 6 | price
# Processing Record 44 of Set 6 | ferkessedougou
# Processing Record 45 of Set 6 | saint george
# Processing Record 46 of Set 6 | saldanha
# Processing Record 47 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 48 of Set 6 | saint-louis
# Processing Record 49 of Set 6 | sovetskiy
# Processing Record 50 of Set 6 | ningan
# City not found. Skipping...
# Processing Record 1 of Set 7 | greymouth
# Processing Record 2 of Set 7 | bathsheba
# Processing Record 3 of Set 7 | bengkulu
# Processing Record 4 of Set 7 | prescott
# Processing Record 5 of Set 7 | el perico
# Processing Record 6 of Set 7 | bandarbeyla
# Processing Record 7 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 8 of Set 7 | richards bay
# Processing Record 9 of Set 7 | los llanos de aridane
# Processing Record 10 of Set 7 | kendari
# Processing Record 11 of Set 7 | murray bridge
# Processing Record 12 of Set 7 | spas-klepiki
# Processing Record 13 of Set 7 | zagare
# Processing Record 14 of Set 7 | alyangula
# Processing Record 15 of Set 7 | peniche
# Processing Record 16 of Set 7 | sola
# Processing Record 17 of Set 7 | auki
# Processing Record 18 of Set 7 | stolin
# Processing Record 19 of Set 7 | gbarnga
# Processing Record 20 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 7 | sept-iles
# Processing Record 22 of Set 7 | obidos
# Processing Record 23 of Set 7 | farah
# Processing Record 24 of Set 7 | bemidji
# Processing Record 25 of Set 7 | acapulco
# Processing Record 26 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 27 of Set 7 | aswan
# Processing Record 28 of Set 7 | lixourion
# Processing Record 29 of Set 7 | margate
# Processing Record 30 of Set 7 | sitka
# Processing Record 31 of Set 7 | caxito
# Processing Record 32 of Set 7 | beyneu
# Processing Record 33 of Set 7 | peleduy
# Processing Record 34 of Set 7 | margherita
# Processing Record 35 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 36 of Set 7 | big rapids
# Processing Record 37 of Set 7 | assiniboia
# Processing Record 38 of Set 7 | port hawkesbury
# Processing Record 39 of Set 7 | flagstaff
# Processing Record 40 of Set 7 | esna
# Processing Record 41 of Set 7 | nantucket
# Processing Record 42 of Set 7 | pizarro
# Processing Record 43 of Set 7 | san-pedro
# Processing Record 44 of Set 7 | terney
# Processing Record 45 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 46 of Set 7 | chicama
# Processing Record 47 of Set 7 | yellowknife
# Processing Record 48 of Set 7 | ambon
# Processing Record 49 of Set 7 | marang
# Processing Record 50 of Set 7 | abengourou
# Processing Record 1 of Set 8 | lasa
# Processing Record 2 of Set 8 | nuuk
# Processing Record 3 of Set 8 | erzin
# Processing Record 4 of Set 8 | yulara
# Processing Record 5 of Set 8 | husavik
# Processing Record 6 of Set 8 | kysyl-syr
# Processing Record 7 of Set 8 | abu jubayhah
# City not found. Skipping...
# Processing Record 8 of Set 8 | sur
# Processing Record 9 of Set 8 | quatre cocos
# Processing Record 10 of Set 8 | griffith
# Processing Record 11 of Set 8 | safaqis
# City not found. Skipping...
# Processing Record 12 of Set 8 | riyadh
# Processing Record 13 of Set 8 | missoula
# Processing Record 14 of Set 8 | vestmannaeyjar
# Processing Record 15 of Set 8 | blonduos
# City not found. Skipping...
# Processing Record 16 of Set 8 | itacoatiara
# Processing Record 17 of Set 8 | pauini
# Processing Record 18 of Set 8 | bulawayo
# Processing Record 19 of Set 8 | magdagachi
# Processing Record 20 of Set 8 | qarayeri
# Processing Record 21 of Set 8 | rock sound
# Processing Record 22 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 23 of Set 8 | kuytun
# Processing Record 24 of Set 8 | seoul
# Processing Record 25 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 26 of Set 8 | yerbogachen
# Processing Record 27 of Set 8 | buta
# Processing Record 28 of Set 8 | lagoa
# Processing Record 29 of Set 8 | aldan
# Processing Record 30 of Set 8 | sento se
# City not found. Skipping...
# Processing Record 31 of Set 8 | plettenberg bay
# Processing Record 32 of Set 8 | beloha
# Processing Record 33 of Set 8 | roseburg
# Processing Record 34 of Set 8 | geraldton
# Processing Record 35 of Set 8 | novyy urengoy
# Processing Record 36 of Set 8 | san jeronimo
# Processing Record 37 of Set 8 | port-gentil
# Processing Record 38 of Set 8 | carnarvon
# Processing Record 39 of Set 8 | labuhan
# Processing Record 40 of Set 8 | zhigansk
# Processing Record 41 of Set 8 | pedernales
# Processing Record 42 of Set 8 | hovd
# Processing Record 43 of Set 8 | porto belo
# Processing Record 44 of Set 8 | motygino
# Processing Record 45 of Set 8 | srednekolymsk
# Processing Record 46 of Set 8 | conceicao do araguaia
# Processing Record 47 of Set 8 | rawson
# Processing Record 48 of Set 8 | djambala
# Processing Record 49 of Set 8 | coruripe
# Processing Record 50 of Set 8 | thurso
# Processing Record 1 of Set 9 | inhambane
# Processing Record 2 of Set 9 | ponta delgada
# Processing Record 3 of Set 9 | kristiansund
# Processing Record 4 of Set 9 | sassandra
# Processing Record 5 of Set 9 | opuwo
# Processing Record 6 of Set 9 | port lincoln
# Processing Record 7 of Set 9 | nikolskiy
# Processing Record 8 of Set 9 | gannan
# Processing Record 9 of Set 9 | lesozavodsk
# Processing Record 10 of Set 9 | aklavik
# Processing Record 11 of Set 9 | kesinga
# Processing Record 12 of Set 9 | chililabombwe
# Processing Record 13 of Set 9 | porto novo
# Processing Record 14 of Set 9 | jiaonan
# Processing Record 15 of Set 9 | kachikau
# City not found. Skipping...
# Processing Record 16 of Set 9 | barabai
# Processing Record 17 of Set 9 | poronaysk
# Processing Record 18 of Set 9 | coahuayana
# Processing Record 19 of Set 9 | meulaboh
# Processing Record 20 of Set 9 | rawlins
# Processing Record 21 of Set 9 | cilegon
# Processing Record 22 of Set 9 | provideniya
# Processing Record 23 of Set 9 | hobyo
# Processing Record 24 of Set 9 | constitucion
# Processing Record 25 of Set 9 | ocos
# Processing Record 26 of Set 9 | cabo san lucas
# Processing Record 27 of Set 9 | moussoro
# Processing Record 28 of Set 9 | siocon
# Processing Record 29 of Set 9 | honningsvag
# Processing Record 30 of Set 9 | nikolayevka
# Processing Record 31 of Set 9 | sao joao da barra
# Processing Record 32 of Set 9 | jalu
# Processing Record 33 of Set 9 | sao luiz gonzaga
# Processing Record 34 of Set 9 | tabulbah
# City not found. Skipping...
# Processing Record 35 of Set 9 | vyshestebliyevskaya
# Processing Record 36 of Set 9 | apache junction
# Processing Record 37 of Set 9 | kutum
# Processing Record 38 of Set 9 | capitan bado
# Processing Record 39 of Set 9 | atbasar
# Processing Record 40 of Set 9 | scunthorpe
# Processing Record 41 of Set 9 | grindavik
# Processing Record 42 of Set 9 | rio gallegos
# Processing Record 43 of Set 9 | narasannapeta
# Processing Record 44 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 45 of Set 9 | luganville
# Processing Record 46 of Set 9 | belyy yar
# Processing Record 47 of Set 9 | parva
# Processing Record 48 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 49 of Set 9 | aksu
# Processing Record 50 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 1 of Set 10 | kudirkos naumiestis
# Processing Record 2 of Set 10 | gainesville
# Processing Record 3 of Set 10 | gondanglegi
# Processing Record 4 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 10 | nogliki
# Processing Record 6 of Set 10 | luderitz
# Processing Record 7 of Set 10 | big spring
# Processing Record 8 of Set 10 | oranjemund
# Processing Record 9 of Set 10 | nuevo imperial
# Processing Record 10 of Set 10 | bilibino
# Processing Record 11 of Set 10 | orange cove
# Processing Record 12 of Set 10 | vila franca do campo
# Processing Record 13 of Set 10 | angarsk
# Processing Record 14 of Set 10 | hvammstangi
# City not found. Skipping...
# Processing Record 15 of Set 10 | guerrero negro
# Processing Record 16 of Set 10 | kurumkan
# Processing Record 17 of Set 10 | kangaatsiaq
# Processing Record 18 of Set 10 | cabedelo
# Processing Record 19 of Set 10 | orlik
# Processing Record 20 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 10 | hirara
# Processing Record 22 of Set 10 | general roca
# Processing Record 23 of Set 10 | sungairaya
# Processing Record 24 of Set 10 | mata
# Processing Record 25 of Set 10 | kununurra
# Processing Record 26 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 10 | biak
# Processing Record 28 of Set 10 | rehoboth
# Processing Record 29 of Set 10 | wolmaranstad
# City not found. Skipping...
# Processing Record 30 of Set 10 | voyvozh
# Processing Record 31 of Set 10 | boende
# Processing Record 32 of Set 10 | guadalupe y calvo
# Processing Record 33 of Set 10 | salisbury
# Processing Record 34 of Set 10 | payo
# Processing Record 35 of Set 10 | leamington
# Processing Record 36 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 10 | agadir
# Processing Record 38 of Set 10 | saint anthony
# Processing Record 39 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 10 | emba
# Processing Record 41 of Set 10 | klaksvik
# Processing Record 42 of Set 10 | atikokan
# Processing Record 43 of Set 10 | pampa
# Processing Record 44 of Set 10 | antsirabe
# Processing Record 45 of Set 10 | porterville
# Processing Record 46 of Set 10 | atar
# Processing Record 47 of Set 10 | rocha
# Processing Record 48 of Set 10 | san quintin
# Processing Record 49 of Set 10 | novyye burasy
# Processing Record 50 of Set 10 | felanitx
# Processing Record 1 of Set 11 | bacolod
# Processing Record 2 of Set 11 | sao miguel do araguaia
# Processing Record 3 of Set 11 | vardo
# Processing Record 4 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 5 of Set 11 | saint-georges
# Processing Record 6 of Set 11 | wana
# Processing Record 7 of Set 11 | ayios matthaios
# City not found. Skipping...
# Processing Record 8 of Set 11 | shieli
# Processing Record 9 of Set 11 | the valley
# Processing Record 10 of Set 11 | palimbang
# Processing Record 11 of Set 11 | vostochnyy
# Processing Record 12 of Set 11 | podosinovets
# Processing Record 13 of Set 11 | jardim
# Processing Record 14 of Set 11 | morshansk
# Processing Record 15 of Set 11 | bubaque
# Processing Record 16 of Set 11 | qaqortoq
# Processing Record 17 of Set 11 | cap malheureux
# Processing Record 18 of Set 11 | iquitos
# Processing Record 19 of Set 11 | fort dodge
# Processing Record 20 of Set 11 | yeppoon
# Processing Record 21 of Set 11 | saint-augustin
# Processing Record 22 of Set 11 | cascais
# Processing Record 23 of Set 11 | dunedin
# Processing Record 24 of Set 11 | trinidad
# Processing Record 25 of Set 11 | mecca
# Processing Record 26 of Set 11 | karratha
# Processing Record 27 of Set 11 | salinas
# Processing Record 28 of Set 11 | vista alegre
# Processing Record 29 of Set 11 | maicao
# Processing Record 30 of Set 11 | grants
# Processing Record 31 of Set 11 | bukama
# Processing Record 32 of Set 11 | trofors
# Processing Record 33 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 34 of Set 11 | yaan
# Processing Record 35 of Set 11 | port antonio
# Processing Record 36 of Set 11 | weihai
# Processing Record 37 of Set 11 | souris
# Processing Record 38 of Set 11 | swinford
# Processing Record 39 of Set 11 | cockburn town
# Processing Record 40 of Set 11 | koboldo
# City not found. Skipping...
# Processing Record 41 of Set 11 | yakeshi
# Processing Record 42 of Set 11 | machico
# Processing Record 43 of Set 11 | yar-sale
# Processing Record 44 of Set 11 | derzhavinsk
# Processing Record 45 of Set 11 | ewa beach
# Processing Record 46 of Set 11 | half moon bay
# Processing Record 47 of Set 11 | yunjinghong
# City not found. Skipping...
# Processing Record 48 of Set 11 | sorland
# Processing Record 49 of Set 11 | tayturka
# Processing Record 50 of Set 11 | san felipe
# Processing Record 1 of Set 12 | batagay-alyta
# Processing Record 2 of Set 12 | eyl
# Processing Record 3 of Set 12 | vila
# Processing Record 4 of Set 12 | wicklow
# Processing Record 5 of Set 12 | anadyr
# Processing Record 6 of Set 12 | khalkhal
# Processing Record 7 of Set 12 | touros
# Processing Record 8 of Set 12 | kursk
# Processing Record 9 of Set 12 | tanout
# Processing Record 10 of Set 12 | avera
# Processing Record 11 of Set 12 | ulaangom
# Processing Record 12 of Set 12 | marawi
# Processing Record 13 of Set 12 | kalmar
# Processing Record 14 of Set 12 | acarau
# Processing Record 15 of Set 12 | ajuchitlan
# Processing Record 16 of Set 12 | egyek
# Processing Record 17 of Set 12 | coquimbo
# Processing Record 18 of Set 12 | pak phanang
# Processing Record 19 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 20 of Set 12 | kedougou
# Processing Record 21 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 22 of Set 12 | buala
# Processing Record 23 of Set 12 | bantogon
# Processing Record 24 of Set 12 | morondava
# Processing Record 25 of Set 12 | kavieng
# Processing Record 26 of Set 12 | parabel
# Processing Record 27 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 28 of Set 12 | ankang
# Processing Record 29 of Set 12 | bosobolo
# Processing Record 30 of Set 12 | tucuman
# Processing Record 31 of Set 12 | aginskoye
# Processing Record 32 of Set 12 | la ronge
# Processing Record 33 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 34 of Set 12 | batticaloa
# Processing Record 35 of Set 12 | pisco
# Processing Record 36 of Set 12 | gachala
# Processing Record 37 of Set 12 | ahuimanu
# Processing Record 38 of Set 12 | carutapera
# Processing Record 39 of Set 12 | wattegama
# Processing Record 40 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 41 of Set 12 | pasni
# Processing Record 42 of Set 12 | elliot lake
# Processing Record 43 of Set 12 | deputatskiy
# Processing Record 44 of Set 12 | anahuac
# Processing Record 45 of Set 12 | qui nhon
# Processing Record 46 of Set 12 | bonthe
# Processing Record 47 of Set 12 | talcahuano
# Processing Record 48 of Set 12 | isabela
# Processing Record 49 of Set 12 | kongsvinger
# Processing Record 50 of Set 12 | kholtoson
# Processing Record 1 of Set 13 | nagorsk
# Processing Record 2 of Set 13 | xichang
# Processing Record 3 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 13 | santiago
# Processing Record 5 of Set 13 | indian head
# Processing Record 6 of Set 13 | grand gaube
# Processing Record 7 of Set 13 | samarai
# Processing Record 8 of Set 13 | tabukiniberu
# City not found. Skipping...
# Processing Record 9 of Set 13 | kidodi
# Processing Record 10 of Set 13 | zdunska wola
# Processing Record 11 of Set 13 | sioux lookout
# Processing Record 12 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 13 | general pico
# Processing Record 14 of Set 13 | cognac
# Processing Record 15 of Set 13 | almajiu
# City not found. Skipping...
# Processing Record 16 of Set 13 | shakhovskaya
# Processing Record 17 of Set 13 | ambilobe
# Processing Record 18 of Set 13 | mendi
# Processing Record 19 of Set 13 | praia da vitoria
# Processing Record 20 of Set 13 | bahia blanca
# Processing Record 21 of Set 13 | san juan
# Processing Record 22 of Set 13 | karlskrona
# Processing Record 23 of Set 13 | zmeinogorsk
# Processing Record 24 of Set 13 | tkvarcheli
# City not found. Skipping...
# Processing Record 25 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 26 of Set 13 | pakdasht
# Processing Record 27 of Set 13 | goure
# Processing Record 28 of Set 13 | presidencia roque saenz pena
# Processing Record 29 of Set 13 | lewistown
# Processing Record 30 of Set 13 | southbridge
# Processing Record 31 of Set 13 | palestine
# Processing Record 32 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 13 | curumani
# Processing Record 34 of Set 13 | cayenne
# Processing Record 35 of Set 13 | calvinia
# Processing Record 36 of Set 13 | nagapattinam
# Processing Record 37 of Set 13 | igarka
# Processing Record 38 of Set 13 | ballina
# Processing Record 39 of Set 13 | esperance
# Processing Record 40 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 13 | port hardy
# Processing Record 42 of Set 13 | alekseyevsk
# Processing Record 43 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 13 | paidha
# Processing Record 45 of Set 13 | maun
# Processing Record 46 of Set 13 | roma
# Processing Record 47 of Set 13 | lata
# Processing Record 48 of Set 13 | udachnyy
# Processing Record 49 of Set 13 | racine
# Processing Record 50 of Set 13 | salym
# Processing Record 1 of Set 14 | lephepe
# City not found. Skipping...
# Processing Record 2 of Set 14 | kloulklubed
# Processing Record 3 of Set 14 | bow island
# Processing Record 4 of Set 14 | beruni
# City not found. Skipping...
# Processing Record 5 of Set 14 | komsomolskiy
# Processing Record 6 of Set 14 | hami
# Processing Record 7 of Set 14 | north las vegas
# Processing Record 8 of Set 14 | jubayl
# City not found. Skipping...
# Processing Record 9 of Set 14 | ulladulla
# Processing Record 10 of Set 14 | vaitape
# Processing Record 11 of Set 14 | tynda
# Processing Record 12 of Set 14 | dolzhanskaya
# Processing Record 13 of Set 14 | blyth
# Processing Record 14 of Set 14 | ossora
# Processing Record 15 of Set 14 | mount gambier
# Processing Record 16 of Set 14 | fort walton beach
# Processing Record 17 of Set 14 | tabalosos
# Processing Record 18 of Set 14 | bobcaygeon
# Processing Record 19 of Set 14 | isangel
# Processing Record 20 of Set 14 | kade
# Processing Record 21 of Set 14 | papara
# Processing Record 22 of Set 14 | neftcala
# Processing Record 23 of Set 14 | seminole
# Processing Record 24 of Set 14 | qufu
# Processing Record 25 of Set 14 | paucartambo
# City not found. Skipping...
# Processing Record 26 of Set 14 | shaartuz
# City not found. Skipping...
# Processing Record 27 of Set 14 | selestat
# Processing Record 28 of Set 14 | tripoli
# Processing Record 29 of Set 14 | daru
# Processing Record 30 of Set 14 | limbang
# Processing Record 31 of Set 14 | jiwani
# Processing Record 32 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 14 | vestmanna
# Processing Record 34 of Set 14 | formosa do rio preto
# Processing Record 35 of Set 14 | jambi
# Processing Record 36 of Set 14 | ternate
# Processing Record 37 of Set 14 | stony mountain
# Processing Record 38 of Set 14 | grand forks
# Processing Record 39 of Set 14 | shimoda
# Processing Record 40 of Set 14 | mazatlan
# Processing Record 41 of Set 14 | wundanyi
# Processing Record 42 of Set 14 | waingapu
# Processing Record 43 of Set 14 | evensk
# Processing Record 44 of Set 14 | saint-leu
# Processing Record 45 of Set 14 | shenjiamen
# Processing Record 46 of Set 14 | elat
# Processing Record 47 of Set 14 | fortuna foothills
# Processing Record 48 of Set 14 | tilichiki
# Processing Record 49 of Set 14 | poum
# Processing Record 50 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 1 of Set 15 | gatton
# Processing Record 2 of Set 15 | ushtobe
# Processing Record 3 of Set 15 | honiara
# Processing Record 4 of Set 15 | tingi
# Processing Record 5 of Set 15 | banjar
# Processing Record 6 of Set 15 | chukhloma
# Processing Record 7 of Set 15 | fiumicino
# Processing Record 8 of Set 15 | teya
# Processing Record 9 of Set 15 | krasnyy chikoy
# Processing Record 10 of Set 15 | malatya
# Processing Record 11 of Set 15 | plainview
# Processing Record 12 of Set 15 | tiruvottiyur
# City not found. Skipping...
# Processing Record 13 of Set 15 | cedral
# Processing Record 14 of Set 15 | galveston
# Processing Record 15 of Set 15 | zeerust
# Processing Record 16 of Set 15 | svetlogorsk
# Processing Record 17 of Set 15 | gorgan
# Processing Record 18 of Set 15 | namatanai
# Processing Record 19 of Set 15 | bambanglipuro
# Processing Record 20 of Set 15 | banda aceh
# Processing Record 21 of Set 15 | yonago
# Processing Record 22 of Set 15 | oistins
# Processing Record 23 of Set 15 | asfi
# Processing Record 24 of Set 15 | kirakira
# Processing Record 25 of Set 15 | halifax
# Processing Record 26 of Set 15 | ust-nera
# Processing Record 27 of Set 15 | naugarzan
# City not found. Skipping...
# Processing Record 28 of Set 15 | muskegon
# Processing Record 29 of Set 15 | kandrian
# Processing Record 30 of Set 15 | egvekinot
# Processing Record 31 of Set 15 | rybachiy
# Processing Record 32 of Set 15 | pangnirtung
# Processing Record 33 of Set 15 | port augusta
# Processing Record 34 of Set 15 | glushkovo
# Processing Record 35 of Set 15 | vire
# Processing Record 36 of Set 15 | dongargaon
# Processing Record 37 of Set 15 | roebourne
# Processing Record 38 of Set 15 | bolekhiv
# Processing Record 39 of Set 15 | sorong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities
print(len(city_data))
# Out:
# 667

# %%
# Convert the array of dictionaries to a pandas dataframe.
city_data_df = pd.DataFrame(city_data)
# Rearrange columns
# Reorder the columns of the dataframe
new_columns = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
city_data_df = city_data_df[new_columns]
city_data_df

city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Castro      BR -24.7911  -50.0119     64.09        94          24
# 1      New Norfolk      AU -42.7826  147.0587     46.99        88         100
# 2            Makat      KZ  47.6469   53.3463     54.90        41           0
# 3  Arraial Do Cabo      BR -22.9661  -42.0278     82.40        61           0
# 4            Birin      NP  26.8865   88.0718     59.59        17           0
# 5          Ushuaia      AR -54.8000  -68.3000     48.20        53          40
# 6          Qaanaaq      GL  77.4840  -69.3632     -1.19        87          17
# 7     Punta Arenas      CL -53.1500  -70.9167     50.00        50          75
# 8            Bluff      NZ -46.6000  168.3333     54.00        95         100
# 9        Busselton      AU -33.6500  115.3333     50.00        97          99
#
#    Wind Speed Current Description
# 0        2.93          few clouds
# 1        2.77     overcast clouds
# 2       12.03           clear sky
# 3        9.22           clear sky
# 4        6.02           clear sky
# 5       10.36    scattered clouds
# 6        3.27          few clouds
# 7       36.82          light rain
# 8        1.99          light rain
# 9        9.10     overcast clouds

# %%
# Create the output file as .CSV (location it will be saved)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_data into a csv.
city_data_df.to_csv(output_data_file, index_label="City_ID")
